# %% [markdown]
# <a href="https://colab.research.google.com/github/joe6302413/SSE-demo/blob/main/SSE_equilibrium_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 克隆專案並進入目錄
# !git clone https://github.com/joe6302413/SSE-demo.git
# %cd SSE-demo

# 2. 安裝 uv 並設定環境變數 (使用 %env 確保全域有效)
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# %env PATH=/root/.local/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# 3. 安裝 Cloudflared (略過已安裝的部分)
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb > /dev/null

# 4. 重要：預先同步套件 (避免啟動 Streamlit 時才在安裝)
print("📦 正在預裝半導體模擬所需套件 (NumPy, Streamlit, etc.)...")
# !uv sync

print("✅ 環境配置完成！")

# %%
import os
import time

# 1. 啟動 Streamlit (背景執行)
# 加上 --server.address=127.0.0.1 提高與雲端隧道的相容性
print("🚀 啟動 Streamlit 服務中...")
os.system("uv run streamlit run equilibrium.py --server.port 8501 --server.address=127.0.0.1 > streamlit.log 2>&1 &")

# 2. 等待服務啟動 (給予 5-10 秒緩衝)
time.sleep(8)

# 3. 啟動 Cloudflare 隧道並顯示連結
print("🔗 正在建立安全隧道，請點擊下方的 trycloudflare.com 連結：")
print("-" * 50)
# !cloudflared tunnel --url http://127.0.0.1:8501 2>&1 | grep -o 'https://.*\.trycloudflare\.com'
print("-" * 50)
