# %% [markdown]
# <a href="https://colab.research.google.com/github/joe6302413/SSE-demo/blob/main/SSE_equilibrium_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 克隆專案
# !git clone https://github.com/joe6302413/SSE-demo.git
# %cd SSE-demo

# 2. 安裝 uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"/root/.local/bin:{os.environ['PATH']}"

# 3. 安裝 localtunnel (用來將 Streamlit 網址轉發出來)
# !npm install -g localtunnel
# Out:
# Cloning into 'SSE-demo'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 30 (delta 14), reused 24 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 142.55 KiB | 17.82 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/SSE-demo/SSE-demo/SSE-demo/SSE-demo
# downloading uv 0.11.7 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 22 packages in 2s
# ⠙
# ⠙3 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙

# %%
# 1. 取得 Colab 伺服器的公開 IP (這是 localtunnel 的安全檢查需要用的)
import urllib
print("您的隧道密碼 (Tunnel Password) 為:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# 2. 背景執行 Streamlit，並透過 localtunnel 轉發
# 我們將 streamlit 執行在 8501 端口，然後讓 npx 把 8501 對外開放
# !uv run streamlit run equilibrium.py & npx localtunnel --port 8501
# Out:
# 您的隧道密碼 (Tunnel Password) 為: 34.86.8.12
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 36 packages in 258ms
# ⠙⠹⠸⠼⠴⠦⠧your url is: https://tangy-apples-find.loca.lt
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.8.12:8501
#
# 2026-04-21 08:46:01.397 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-04-21 08:46:01.511 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-04-21 08:46:01.728 Please replace `use_container_width` with `width`.
#
# ...
